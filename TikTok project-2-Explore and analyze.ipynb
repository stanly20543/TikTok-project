# %% [markdown]
# ## **Clonclusion**
#
# 1. As exploring the data by each `video_count` variables and `status` variables, there numbers of outlier might be the valid data.
# 2. There are far fewer verified users than unverified users, but if a user is verified, they are much more likely to post opinions.
# 3. For both claims and opinions, there are many more active authors than banned authors or authors under review; however,for  the proportion of active authors is far greater for opinion videos than for claim videos. It seems that authors who post claim videos are more likely to come under review or get banned.
# 4. It is still hard to verify and predict the video is claim or opinion. It needs more distinctive variables like video type, classification or the hash tag of video for further investigating the data.

# %% [markdown]
# ## **EXploring and Analyzing Data**

# %% [markdown]
# #### **Import packages**

# %%
# Import packages for data manipulation and visualization
try :
    import pandas as pd
    import numpy as np
    import matplotlib.pyplot as plt
    import seaborn as sns
    print("Import successfully")
except:
    print("Import fail")
# Out:
# Import successfully

# %%
# Load dataset into dataframe
df = pd.read_csv("tiktok_dataset.csv")

# %%
# Display and examine the first few rows of the dataframe
df.head()
# Out:
#    # claim_status    video_id  video_duration_sec  \
# 0  1        claim  7017666017                  59
# 1  2        claim  4014381136                  32
# 2  3        claim  9859838091                  31
# 3  4        claim  1866847991                  25
# 4  5        claim  7105231098                  19
#
#                             video_transcription_text verified_status  \
# 0  someone shared with me that drone deliveries a...    not verified
# 1  someone shared with me that there are more mic...    not verified
# 2  someone shared with me that american industria...    not verified
# 3  someone shared with me that the metro of st. p...    not verified
# 4  someone shared with me that the number of busi...    not verified
#
#   author_ban_status  video_view_count  video_like_count  video_share_count  \
# 0      under review          343296.0           19425.0              241.0
# 1            active          140877.0           77355.0            19034.0
# ...

# %%
# Get the size of the data
df.size
# Out:
# 232584

# %%
# Get the shape of the data
df.shape
# Out:
# (19382, 12)

# %%
# Get basic information about the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19382 entries, 0 to 19381
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   #                         19382 non-null  int64
#  1   claim_status              19084 non-null  object
#  2   video_id                  19382 non-null  int64
#  3   video_duration_sec        19382 non-null  int64
#  4   video_transcription_text  19084 non-null  object
#  5   verified_status           19382 non-null  object
#  6   author_ban_status         19382 non-null  object
#  7   video_view_count          19084 non-null  float64
#  8   video_like_count          19084 non-null  float64
#  9   video_share_count         19084 non-null  float64
#  10  video_download_count      19084 non-null  float64
#  11  video_comment_count       19084 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 1.8+ MB

# %%
# Generate a table of descriptive statistics
df.describe()
# Out:
#                   #      video_id  video_duration_sec  video_view_count  \
# count  19382.000000  1.938200e+04        19382.000000      19084.000000
# mean    9691.500000  5.627454e+09           32.421732     254708.558688
# std     5595.245794  2.536440e+09           16.229967     322893.280814
# min        1.000000  1.234959e+09            5.000000         20.000000
# 25%     4846.250000  3.430417e+09           18.000000       4942.500000
# 50%     9691.500000  5.618664e+09           32.000000       9954.500000
# 75%    14536.750000  7.843960e+09           47.000000     504327.000000
# max    19382.000000  9.999873e+09           60.000000     999817.000000
#
#        video_like_count  video_share_count  video_download_count  \
# count      19084.000000       19084.000000          19084.000000
# mean       84304.636030       16735.248323           1049.429627
# std       133420.546814       32036.174350           2004.299894
# ...

# %% [markdown]
# #### **Check the distribution of `video_duration_sec`**

# %%
# Create a boxplot to visualize distribution of `video_duration_sec`
plt.figure(figsize = (5, 1))
plt.title("video_duration_sec")
sns.boxplot(x = df["video_duration_sec"])
# Out:
# <Axes: title={'center': 'video_duration_sec'}, xlabel='video_duration_sec'>

# %%
# Create a histogram
plt.figure(figsize = (5, 3))
sns.histplot(x = df["video_duration_sec"], bins = range(0, 61, 5), hue = df["claim_status"])
plt.title("Video duration histogram")
# Out:
# Text(0.5, 1.0, 'Video duration histogram')

# %% [markdown]
# #### **Check the distribution of `video_view_count`**

# %%
# Create a boxplot to visualize distribution of `video_view_count`
plt.figure(figsize = (5, 1))
plt.title("video_view_count")
sns.boxplot(x = df["video_view_count"])
# Out:
# <Axes: title={'center': 'video_view_count'}, xlabel='video_view_count'>

# %%
# Create a histogram
plt.figure(figsize = (5, 3))
sns.histplot(x = df["video_view_count"], bins = range(0, (10**6+1), 10**5), hue = df["claim_status"])
plt.title("Video view count histogram")
# Out:
# Text(0.5, 1.0, 'Video view count histogram')

# %% [markdown]
# #### **Check the distribution of `video_like_count`**

# %%
# Create a boxplot to visualize distribution of `video_like_count`
plt.figure(figsize = (5, 1))
plt.title("video__like_count")
sns.boxplot(x = df["video_like_count"], fliersize= 3)
# Out:
# <Axes: title={'center': 'video__like_count'}, xlabel='video_like_count'>

# %%
# Create a histogram
plt.figure(figsize = (5, 3))
ax = sns.histplot(x = df["video_like_count"], bins = range(0, (7*10**5+1), 10**5), hue = df["claim_status"])
labels = [0] + [str(i) + 'k' for i in range(100, 701, 100)]
ax.set_xticks(range(0,7*10**5+1,10**5), labels=labels)
plt.title("Video like count histogram")
# Out:
# Text(0.5, 1.0, 'Video like count histogram')

# %% [markdown]
# #### **Check the distribution of `video_comment_count`**

# %%
# Create a boxplot to visualize distribution of `video_comment_count`
plt.figure(figsize = (5, 1))
plt.title("video_comment_count")
sns.boxplot(x = df["video_comment_count"], fliersize=3)
# Out:
# <Axes: title={'center': 'video_comment_count'}, xlabel='video_comment_count'>

# %%
# Create a histogram
plt.figure(figsize = (5, 3))
sns.histplot(x = df["video_comment_count"], bins = range(0, 3001, 100), hue = df["claim_status"])
plt.title("Video comment count histogram")
# Out:
# Text(0.5, 1.0, 'Video comment count histogram')

# %% [markdown]
# #### **Check the distribution of `video_share_count`**

# %%
# Create a boxplot to visualize distribution of `video_share_count`
plt.figure(figsize=(5,1))
plt.title('video_share_count')
sns.boxplot(x=df['video_share_count'], fliersize=3);

# %%
# Create a histogram
plt.figure(figsize=(5,3))
sns.histplot(x = df['video_share_count'], bins=range(0,(270001),10000), hue = df["claim_status"])
plt.title('Video share count histogram')
# Out:
# Text(0.5, 1.0, 'Video share count histogram')

# %% [markdown]
# #### **Check the distribution of `video_download_count`**

# %%
# Create a boxplot to visualize distribution of `video_download_count`
plt.figure(figsize=(5,1))
plt.title('video_download_count')
sns.boxplot(x=df['video_download_count'], fliersize=3)
# Out:
# <Axes: title={'center': 'video_download_count'}, xlabel='video_download_count'>

# %%
# Create a histogram
plt.figure(figsize=(5,3))
sns.histplot(x = df['video_download_count'], bins=range(0,(15001),500), hue = df["claim_status"])
plt.title('Video download count histogram')
# Out:
# Text(0.5, 1.0, 'Video download count histogram')

# %% [markdown]
# #### **Compare the number of `verified_status` in `claim_status`**

# %%
# Create a histogram
plt.figure(figsize=(7, 4))
sns.histplot(data = df,
             x = "claim_status",
             hue = "verified_status",
             multiple = "dodge",
             shrink = 0.9)
# Out:
# <Axes: xlabel='claim_status', ylabel='Count'>

# %% [markdown]
# #### **Compare the number of `author_ban_status` in `claim_status`**

# %%
# Create a histogram
plt.figure(figsize=(7, 4))
sns.histplot(data = df,
            x = "claim_status",
            hue = "author_ban_status",
            hue_order = ["active", "under review", "banned"],
            multiple = "dodge",
            shrink = 0.9,
            palette = {'active':'green', 'under review':'orange', 'banned':'red'},
            alpha = 0.5 )
plt.title("Claim status by author ban status - counts")
# Out:
# Text(0.5, 1.0, 'Claim status by author ban status - counts')

# %% [markdown]
# #### **Check the median of `video_view_count` in `author_ban_status`**

# %%
# Create a bar plot
ban_status_counts = df.groupby(['author_ban_status']).median(numeric_only=True).reset_index()

plt.figure(figsize=(5,3))
sns.barplot(data=ban_status_counts,
            x='author_ban_status',
            y='video_view_count',
            order=['active', 'under review', 'banned'],
            palette={'active':'green', 'under review':'orange', 'banned':'red'},
            alpha=0.5)
plt.title('Median view count by ban status')
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_4440\3886539663.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=ban_status_counts,
# Text(0.5, 1.0, 'Median view count by ban status')

# %% [markdown]
# #### **Check the `video_view_count` in `claim_status`**

# %%
# Calculate the median view count for claim status.
df.groupby(["claim_status"])["video_view_count"].median()
# Out:
# claim_status
# claim      501555.0
# opinion      4953.0
# Name: video_view_count, dtype: float64

# %%
# Create a pie graph
plt.figure(figsize=(3,3))
plt.pie(df.groupby('claim_status')['video_view_count'].sum(), labels=['claim', 'opinion'])
plt.title('Total views by video claim status')
# Out:
# Text(0.5, 1.0, 'Total views by video claim status')

# %% [markdown]
# #### **The number of outliers for each variable**

# %%
count_cols = ['video_view_count',
              'video_like_count',
              'video_share_count',
              'video_download_count',
              'video_comment_count',
              ]

for column in count_cols:
    q1 = df[column].quantile(0.25)
    q3 = df[column].quantile(0.75)
    iqr = q3 - q1
    median = df[column].median()
    outlier_threshold = median + 1.5*iqr

    # Count the number of values that exceed the outlier threshold
    outlier_count = (df[column] > outlier_threshold).sum()
    print(f'Number of outliers, {column}:', outlier_count)
# Out:
# Number of outliers, video_view_count: 2343
# Number of outliers, video_like_count: 3468
# Number of outliers, video_share_count: 3732
# Number of outliers, video_download_count: 3733
# Number of outliers, video_comment_count: 3882

# %% [markdown]
# #### **Check the distribution of `claim_status` for each variable**

# %% [markdown]
# ##### For example : The scatterplot for `video_view_count` and `video_like_count`

# %%
# Create a scatterplot of `video_view_count` versus `video_like_count` according to 'claim_status'
sns.scatterplot(x=df["video_view_count"], 
                y=df["video_like_count"],
                hue=df["claim_status"], 
                s = 10)
plt.show()

# %%
# Create a scatterplot of ``video_view_count` versus `video_like_count` for opinions only
opinion = df[df['claim_status'] == 'opinion']
sns.scatterplot(x = opinion["video_view_count"], 
                y = opinion["video_like_count"], 
                s = 10)
plt.show()
